# %% [markdown]
# # Operating system calls
#
# It's possible to use python to perform command line calls
#
# We can do this with the os module

# %%
import os

# %% [markdown]
# ## name of operating system
#
# We can get the operating system we're working on
#
# 1. nt is windows
# 2. posix is all unix based systems (Mac, Linux, ...)

# %%
print(os.name)

if os.name == "nt":
    print("You are running a Windows-based computer")
elif os.name == "posix":
    print("You are running Mac or Linux")
else:
    print("Error in determining OS")
# Out:
# nt
# You are running a Windows-based computer

# %% [markdown]
# ## working directory

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jharnack\\Documents\\AI-ML Python Scripts'

# %%
print(os.getcwd())
# Out:
# C:\Users\jharnack\Documents\AI-ML Python Scripts

# %% [markdown]
# ## contents of directory

# %%
os.listdir(".")
# Out:
# ['.ipynb_checkpoints',
#  'Debugging.ipynb',
#  'flow_control.ipynb',
#  'functions.ipynb',
#  'git-cheat-sheet-education.pdf',
#  'Github Uploads (UI version).pdf',
#  'intro_to_python_data_types.ipynb',
#  'OOP_in_python.ipynb',
#  'Operating_system_module.ipynb',
#  'Python Pre Work.ipynb']

# %%
os.listdir('C:\\Users\\jharnack\\Downloads')
# Out:
# ['003891_folio_e_billing114399173.pdf',
#  '01151607.tif.assetdownload.zip',
#  '01151628.tif',
#  '033_Billings_by_Product_Hierarchy_data (1).csv',
#  '033_Billings_by_Product_Hierarchy_data.csv',
#  '04081406.tif',
#  '06-Armando-Bonilla-Fernandez-Salland-Engineering-MEMS-Seminar-2019.pdf',
#  '06041513.tif.assetdownload.zip',
#  '06041517.tif.assetdownload.zip',
#  '06041524.tif.assetdownload.zip',
#  '074_pv_Billings_Trend_data.csv',
#  '075_pv_Billings_Table_data (1).csv',
#  '075_pv_Billings_Table_data.csv',
#  '08231602.tif',
#  '0831',
#  '0_SEC_Walkthrough_File_Sharing_Permissions.pdf',
#  '11161206.tif',
#  '11_PEL-2000.doc',
#  '142785b_Jan15c.pdf',
#  '1KW-2996-2_ACS_Basic_Datasheet_040619.pdf',
#  '1KW-60240-1_S530_S530-HV_Datasheet.pdf',
#  '1KW-60288-1_2461_Datasheet_112119 (1).pdf',
#  '1KW-60288-1_2461_Datasheet_112119 (2).pdf',
#  '1KW-60288-1_2461_Datasheet_112119.pdf',
#  '1KW-60640-0_FourPointCollinear_4200A-SCS_AN.pdf',
#  '1KW-60645-0_C-V_CharMOSCapacitors_4200A-SCS.pdf',
#  '1KW-60780-4_4200A-SCS Datasheet_020619.pdf',
#  '1KW-60904-2_2450_Datasheet_112119.pdf',
#  '1KW-60906-0_Series2600B_DataSheet (1).pdf',
#  '1KW-60906-0_Series2600B_DataSheet (2).pdf',
#  '1KW-60906-0_Series2600B_DataSheet (3).pdf',
#  '1KW-60906-0_Series2600B_DataSheet.pdf',
#  '1KW-60906-0_Series_2600BDatasheet_112718.pdf',
#  '1KW-61212-0_PulseTestingWhitePaper.pdf',
#  '1KW-61394-0_2606B_Datasheet_042418 (1).pdf',
#  '1KW-61394-0_2606B_Datasheet_042418.pdf',
#  '1KW-61523-0_2470_Datasheet_042419.pdf',
#  '1KW-61621-0_2520_Datasheet_0919.pdf',
#  '1KW-61659-0_2601B-PULSE_Datasheet_041620-0.pdf',
#  '2016 Samsung Success Stories .pptx',
#  '2017 F&S - Global Semiconductor ATE Market V_Mar17 FOR NI INTERNAL USE.pdf',
#  '20170823_101024.jpg',
#  '2018 Bosch CCS Introduction to NI.pdf',
#  '2018 F&S - Electronics T&M Equipment Market (K17C-30) FOR NI INTERNAL USE.pdf',
#  '2018 Semiconductor Roadshow DC Measurements_v2 (1).pptx',
#  '2018 Semiconductor Roadshow DC Measurements_v2.pptx',
#  '2018 Semiconductor Roadshow DC Measurements_v2_KB.pptx',
#  '2018 Semiconductor Roadshow DC Measurements_v2_KB_jh_JG.pptx',
#  '2018-06-26-Semiconductor_Test_Software_Roadmap_(Redacted)-484588.simple.html',
#  '2019 Barcelona Engagement Phases Sales Guide - Sept 25 2019 (1).docx',
#  '2019 Barcelona Engagement Phases Sales Guide - Sept 25 2019.docx',
#  '2019 Master Policy ARAG.pdf',
#  '2019-03-20.pdf',
#  '20191015114451.ics',
#  '20191028123003.ics',
#  '2020 Corporate Template FINAL.potx',
#  '20200226_PXIe-4147_01.tif.assetdownload.zip',
#  '20200226_PXIe-4147_02.tif.assetdownload.zip',
#  '2020_ADM_ProductPlanning_Bookings_TableauServer.twbx',
#  '2182A-15912 (1).pdf',
#  '2182A-15912.pdf',
#  '2280S DataSheet_0 (1).pdf',
#  '2280S DataSheet_0.pdf',
#  '2281S Data Sheet2.pdf',
#  '237.pdf',
#  '2400_SMU_Datasheet_1KW-2798-1 (1).pdf',
#  '2400_SMU_Datasheet_1KW-2798-1.pdf',
#  '2400_SMU_Datasheet_1KW-2798-1_011719.pdf',
#  '2450 TSP Commands Resistance.pdf',
#  '2450-900-01_D_May_2015_User-9377AFD9.pdf',
#  '2450-901-01_D_May_2015_Ref.pdf',
#  '2460_Datasheet_1KW-60905-0 (1).pdf',
#  '2460_Datasheet_1KW-60905-0 (2).pdf',
#  '2460_Datasheet_1KW-60905-0 (3).pdf',
#  '2460_Datasheet_1KW-60905-0.pdf',
#  '2461-DataSheet (1).pdf',
#  '2461-DataSheet (2).pdf',
#  '2461-DataSheet (3).pdf',
#  '2461-DataSheet.pdf',
#  '2502 (1).pdf',
#  '2502 (2).pdf',
#  '2502.pdf',
#  '2510-2510AT (1).pdf',
#  '2510-2510AT (2).pdf',
#  '2510-2510AT.pdf',
#  '2520 (1).pdf',
#  '2520 (2).pdf',
#  '2520 (3).pdf',
#  '2520.pdf',
#  '2600BS-901-01_C_Aug_2016_2.pdf',
#  '2600S-900-01(C-Jan2008)(User).pdf',
#  '2651A (1).pdf',
#  '2651A (2).pdf',
#  '2651A (3).pdf',
#  '2651A (4).pdf',
#  '2651A.pdf',
#  '2657A_HighPowerSourceMeterSMU (1).pdf',
#  '2657A_HighPowerSourceMeterSMU.pdf',
#  '2ef2174e-f2bb-a7f2-befa-f0e6a0bc8b60.xlsx',
#  '3680-E.pdf',
#  '370736u (1).zip',
#  '370736u.zip',
#  '3766369_6203_ENG_A_W.pdf',
#  '37W_60227_1_Power-Consumption.pdf',
#  '4 ways to stay safe online.pdf',
#  '4135 CV with Step Delta Time (1).zip',
#  '4135 CV with Step Delta Time.zip',
#  '416x DX Pogo Cable.PDF',
#  '4200 CV ApplicationsGuide.pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (1).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (2).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (3).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (4).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (5).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618 (6).pdf',
#  '4200A-SCS Datasheet_1KW-60780-3_031618.pdf',
#  '5 Tips for Optimizing SMUs Demos.zip',
#  '5280412-01',
#  '5280412-01.zip',
#  '5G RF Front End Overview_EE Times.pdf',
#  '5x4139 Load Sharing (1) (1).flv',
#  '5x4139 Load Sharing (1).flv',
#  '6220-6221.pdf',
#  '6430 (1).pdf',
#  '6430.pdf',
#  '6487-901-01(B-Mar2011)(Ref).pdf',
#  '6517B-Datasheet_1KW-60280-1 (1).pdf',
#  '6517B-Datasheet_1KW-60280-1.pdf',
#  '6E12FBEF08E66CC00455D9C6DFC5FD5E.ics',
#  '7072-HV.pdf',
#  '707B-708B (1).pdf',
#  '707B-708B (2).pdf',
#  '707B-708B (3).pdf',
#  '707B-708B (4).pdf',
#  '707B-708B (5).pdf',
#  '707B-708B (6).pdf',
#  '707B-708B (7).pdf',
#  '707B-708B.pdf',
#  '707B-900-01(B-Jun2013).pdf',
#  '707B-901-01B_Jan_2015.pdf',
#  '707B-903-01.pdf',
#  '7174A_901_01A.pdf',
#  '782620-01_BOM.xls',
#  '787a1fb4-2645-4b87-a051-5912daf04e0d.ics',
#  'Account Roadshow_NI SMU Overview 2016_Feb28.pptx',
#  'Accuracy IV - Advanced Techniques for Removing Noise.pdf',
#  'Acc_Cables-57323 (1).pdf',
#  'Acc_Cables-57323.pdf',
#  'Acquiring Low Level Signals with Precision DC Instruments_2_27.pptx',
#  'Acquisition Collision.pptx',
#  'ACS.pdf',
#  'ADA4870 (1).pdf',
#  'ADA4870.pdf',
#  'ADI Account Plan_2019_FINAL.pptx',
#  'agile163940958.xlsx',
#  'agile223138255.docx',
#  'agile223481585.docx',
#  'agile76366521.zip',
#  'agile76366522.zip',
#  'agilent_b1500',
#  'agilent_b1500.zip',
#  'agilent_b2900_series',
#  'agilent_b2900_series.zip',
#  'agilent_e4980',
#  'agilent_e4980 (1)',
#  'agilent_e4980 (1).zip',
#  'agilent_e4980.zip',
#  'ag_tc_m4x_b08_1_SCAN.DIGIPATSRC',
#  'Alarms - Competitive Analysis.docx',
#  'Anaconda3-2019.10-Windows-x86_64.exe',
#  'Analog Theory of Operation.docx',
#  'APAC Core Test and RF Q4 & 2017 Assessment 02062018.pptx',
#  'appointment (1).ics',
#  'appointment (2).ics',
#  'Appointment.ics',
#  'approved_addendum_template_144126_12768689_20190329045552_860002932.pdf',
#  'Atom Resolution and Accuracy (1).msg',
#  'Atom Resolution and Accuracy.msg',
#  'Austin Sunshine Camps 2020 Donation Receipt.pdf',
#  'Azrael - Analog Theory of Operation.docx',
#  'Azrael Hours from Oracle Projects.xlsx',
#  'BLP0427M9S20_0427M9S20G.PDF',
#  'BLP0427M9S20_application-notes.zip',
#  'Blue Cross Blue Shield - Brown Bag.ics',
#  'bourns_inductor.pdf',
#  'brainstorm.pptx',
#  'Broadcom System.zip',
#  'Broadcom_Test-Result_20180912.pptx',
#  'Business Case Template - ppt (1).pptx',
#  'Business Case Template - ppt (2).pptx',
#  'Business Case Template - ppt.pptx',
#  'Business Case template - with help.docx',
#  'C2991500',
#  'Cables_071017 (1).pdf',
#  'Cables_071017.pdf',
#  'CAGR - Billings - Base.xlsx',
#  'Calibration services update_Jose Miguel Pena_3 Nov 2016.pptx',
#  'ccsetup545.exe',
#  'Chroma_20174Q_Presentation-20180222-EN (1).pdf',
#  'Chroma_20174Q_Presentation-20180222-EN.pdf',
#  'Chroma_20181Q_Presentation-20180430-EN_Present.pdf',
#  'Chroma_20183Q_Presentation-20181030-EN_Present.pdf',
#  'Chroma_20193Q_Presentation-20191031-EN_Present.pdf',
#  'Ciro STS Backlog Research',
#  'ClariusV1.3_0',
#  'ClariusV1.7_4200A-CLARIUS-V1.7',
#  'ClariusV1.7_4200A-CLARIUS-V1.7.zip',
#  'CoaxialSwitches_WEB_2_.pdf',
#  'Cobra Cycle 11 Comittment.pptx',
#  'Company Narrative Leadership Slides_2018_4 (1).pptx',
#  'competition positioning.pdf',
#  'ConceptTesting_Wires.zip',
#  'Consolidated Financial Report Q1, 2018.pdf',
#  'contacts (1).csv',
#  'contacts.csv',
#  'contact_check (1).html',
#  'contact_check (2).html',
#  'contact_check (3).html',
#  'contact_check (4).html',
#  'contact_check (5).html',
#  'contact_check.html',
#  'Core Test Billings Pull (1).xlsx',
#  'Core Test Billings Pull (10).xlsx',
#  'Core Test Billings Pull (11).xlsx',
#  'Core Test Billings Pull (12).xlsx',
#  'Core Test Billings Pull (13).xlsx',
#  'Core Test Billings Pull (14).xlsx',
#  'Core Test Billings Pull (15).xlsx',
#  'Core Test Billings Pull (16).xlsx',
#  'Core Test Billings Pull (17).xlsx',
#  'Core Test Billings Pull (18).xlsx',
#  'Core Test Billings Pull (19).xlsx',
#  'Core Test Billings Pull (2).xlsx',
#  'Core Test Billings Pull (20).xlsx',
#  'Core Test Billings Pull (21).xlsx',
#  'Core Test Billings Pull (22).xlsx',
#  'Core Test Billings Pull (23).xlsx',
#  'Core Test Billings Pull (24).xlsx',
#  'Core Test Billings Pull (25).xlsx',
#  'Core Test Billings Pull (3).xlsx',
#  'Core Test Billings Pull (4).xlsx',
#  'Core Test Billings Pull (5).xlsx',
#  'Core Test Billings Pull (6).xlsx',
#  'Core Test Billings Pull (7).xlsx',
#  'Core Test Billings Pull (8).xlsx',
#  'Core Test Billings Pull (9).xlsx',
#  'Core Test Billings Pull.xlsx',
#  'Core Test Project Tiering Q1 2018.pptx',
#  'Core Test QBD Aug 2018 Distribution.pptx',
#  'Core Test RnD Q4 2017 QBD distribution.pptx',
#  'Corporate Template 2017_16x9_Final.potx',
#  'Counters.zip',
#  'CustomerData3.zip',
#  'CustomerImages.zip',
#  'CustomerImages2.zip',
#  'Customers_info.rar',
#  'CV MeasTips WP.pdf',
#  'CV with Step Delta Time.vi',
#  'Cyber Security Form.xlsx',
#  'DashlaneInst.exe',
#  'DC Converter Demo with NI 4139.docx',
#  'DCE 190012 EB Analyseur.zip',
#  'Demo Script and Instructions Guidance.docx',
#  'Demo Script and Instructions Guidance_SMU Demo_AT.docx',
#  'Design your own VCOs and get much better phase noise.pptx',
#  'desktop.ini',
#  'Digital Cable_def_attr.xlsx',
#  'DLCP_PV SOlarCellAppNote.pdf',
#  'DMM7510-Datasheet_1KW-60022-2 (1).pdf',
#  'DMM7510-Datasheet_1KW-60022-2 (2).pdf',
#  'DMM7510-Datasheet_1KW-60022-2 (3).pdf',
#  'DMM7510-Datasheet_1KW-60022-2 (4).pdf',
#  'DMM7510-Datasheet_1KW-60022-2.pdf',
#  'DPS Comparison.pptx',
#  'Draft_Flow-Chart-IMP.jpg',
#  'DriverReadmes.zip',
#  'driver_ivi_matlab_AgilentE4980A_1_2_1_0_x64.msi',
#  'Dropping Support for 32-Bit Windows OSes.pptx',
#  'DS82_Complete.pdf',
#  'ec7fe2dd-ca7b-40cf-a85a-60ddc17c9c28.ics',
#  'ECM_Ripple2550_3-20-13 (1).pdf',
#  'ECM_Ripple2550_3-20-13.pdf',
#  'energies-11-01184 (1).pdf',
#  'energies-11-01184.pdf',
#  'EOL Letter - Template 2012.docx',
#  'EOL Letter - Template 2018.docx',
#  'ESPP.xps',
#  'ESPP_Prospectus_.4.5.17 (1).pdf',
#  'ESPP_Prospectus_.4.5.17.pdf',
#  'event (1).ics',
#  'event (2).ics',
#  'event.ics',
#  'EventCalendarServlet (1).ics',
#  'EventCalendarServlet.ics',
#  'Exploration Go No-Go Meeting.pptx',
#  'Expo Training_Parametric Test with NI SMUs.pptx',
#  'export.xlsx',
#  'Ex_Files_Intro_Data_Science.zip',
#  'FFT_UX',
#  'FFT_UX.zip',
#  'FGEN - Voltage.zip',
#  'ficonTEC @ EPIC-Yelo on Photonics Testing 160218.pdf',
#  'Firestorm Aux Power Budget.xlsx',
#  'flux-setup.exe',
#  'Folio-A-Attachment.pdf',
#  'FOR NI INTERNAL USE ONLY - 2018 IC Insights - The McClean Report (Full).pdf',
#  'Frequency Synthesizers - The Past , the Present, the Future, and Beyond (1).pptx',
#  'Frequency Synthesizers - The Past , the Present, the Future, and Beyond.pptx',
#  "From Campus to Career - WSJ's Sue Shellenbarger.pdf",
#  'Full Catering Menu 2019.pdf',
#  'Glossary_Data_Science_Foundations_Fundamentals.zip',
#  'GODADDY Phase Matrix Login Info.txt',
#  'google-python-exercises',
#  'google-python-exercises.zip',
#  'Guest-List-Template-Personal (1).xlsx',
#  'Guest-List-Template-Personal.csv',
#  'Guest-List-Template-Personal.xlsx',
#  'GX3104DS.pdf',
#  'Handouts for GSMC LCR Session.pptx',
#  'Harnack 2016 Performance Review.docx',
#  'High Power Platform V2A Jan 2019.pptx',
#  'Highly Parallel Wafer-Level Reliability Systems With PXI SMUs_v3_KB.pptx',
#  'How to Succeed Bridging the Gap Between Characterization and Production Test_Semi (1).pdf',
#  'How to Succeed Bridging the Gap Between Characterization and Production Test_Semi.pdf',
#  'HW Features Proposal template - ppt.pptx',
#  'hwFLEX.pdf',
#  'iais_technology_refresh_datasheet.pdf',
#  'Idea Proposal template.pptx',
#  'IMEC 2019 EIA Submission.pdf',
#  'index (1).html',
#  'index (2).html',
#  'index (3).html',
#  'index (4).html',
#  'index (5).html',
#  'index.html',
#  'InstrumentStudio 2018 Introduction.pptx',
#  'InstrumentStudio 2018 SP2 Feature Deck.pptx',
#  'InstrumentStudio Closed Door Concept Testing.pptx',
#  'Integrating_Sphere_AN (1).pdf',
#  'Integrating_Sphere_AN.pdf',
#  'Intel Bookings & Billings & Backlog 02-12-2018.xlsx',
#  'International Shipping or Hand Carry Request Form - 01022018.docx',
#  'Investor-Call-Deck-11-26-2018.pdf',
#  'ipa_16-068_ni_pxie_4135_low_current_smu_28june2016.docx',
#  'itc55100c_ds_rev_02_02_14.pdf',
#  'Jake_Harnack_informal.tif.assetdownload',
#  'Jake_Harnack_informal.tif.assetdownload.zip',
#  'keithley_24xx',
#  'keithley_24xx.zip',
#  'Keithley_2600_Series(2.5.0)_LV_2009',
#  'Keithley_2600_Series(2.5.0)_LV_2009 (1)',
#  'Keithley_2600_Series(2.5.0)_LV_2009 (1).zip',
#  'Keithley_2600_Series(2.5.0)_LV_2009.zip',
#  'Kelley_M_resume.docx',
#  'Keyless Remote Removal Replacement and Test.pdf',
#  'KI4200.llb',
#  'LabVIEW NXG Cobra Beta 1 Public Announcement.pdf',
#  'large-coreblock (1).png',
#  'large-coreblock (2).png',
#  'large-coreblock.png',
#  'large.png',
#  'LCR Measurements API Feature Specification.docx',
#  'LCR Stimulus API Feature Specification.docx',
#  'LEGAL-3329-PMI-FreeFlight Acquisition Corp-MNDA-draft-2019sep25-NI-HB (1).docx',
#  'LEGAL-3329-PMI-FreeFlight Acquisition Corp-MNDA-draft-2019sep25-NI-HB.docx',
#  'LowLevelHandbook_7Ed (1).pdf',
#  'LowLevelHandbook_7Ed (2).pdf',
#  'LowLevelHandbook_7Ed (3).pdf',
#  'LowLevelHandbook_7Ed (4).pdf',
#  'LowLevelHandbook_7Ed.pdf',
#  'Margin율 계산 v2.0_SEMCO_20190108.xlsm',
#  'Market Basket Results.png',
#  'MAX_Reports_BAD.zip',
#  'Measuring-amplifier-DC-offset-voltage--PSRR--CMRR--and-open-loop-gain.pdf',
#  'medium.png',
#  'MFL69677801_04_Q_171122.pdf',
#  'Mobile Campaign Brochure (EN).pdf',
#  'Modern Workplace 2019 impact - Jive Migration.msg',
#  'mod_assy_red_tornado_v2_6-5-18.pdf',
#  'MOSFET Capacitance Measurement (1).zip',
#  'MOSFET Capacitance Measurement.zip',
#  'Multi Channel SMU - Test File (1).vi',
#  'Multi Channel SMU - Test File (2).vi',
#  'Multi Channel SMU - Test File.vi',
#  'n1cgr22w.exe',
#  'n23gz15w.exe',
#  'Narrative 2019 May_16x9.pptx',
#  'NI driven IN-FAB parametric tester.pptx',
#  'NI Guests_VIP 2018 (1).pptx',
#  'NI Guests_VIP 2018.pptx',
#  'NI Linux Device Drivers (July 2018) (1).zip',
#  'NI Linux Device Drivers (July 2018).zip',
#  'NI Part Numbers for QuickSyns.xlsx',
#  'NI support request pics.zip',
#  'NI Talk Data Analysis_Marketing.xlsx',
#  'ni-dcpower_18.1_en.nihelp',
#  'ni-dcpower_18.2_en (1).nihelp',
#  'ni-dcpower_18.2_en.nihelp',
#  'NI-HSDIO Test Panel.zip',
#  'NI272X1300.exe',
#  'nidcpower-1.1.5-py2.py3-none-any.whl',
#  'nidcpower-1.1.5.tar.gz',
#  'NIDEC MEMS parametric tester G-100.pdf',
#  'nidigital-0.2.1-py2.py3-none-any.whl',
#  'nidigital-0.2.1.tar.gz',
#  'NIer to NIer Trivia Night - BYOD!.ics',
#  'NIer to NIer Trivia Night! (1).ics',
#  'NIer to NIer Trivia Night!.ics',
#  'NIQuote_1109263_(865191-UPG1)_Hisilicon.pdf',
#  'niRF - QuickSyn Single Install.vipc',
#  'NIWeek 2013 - Demo Scripts from AT Pavilion.zip',
#  'NIWeek 2018 Demo Script Images (1).pdf',
#  'NIWeek 2018 Demo Script Images.pdf',
#  'NIWeek Demos.zip',
#  'NIWeek_2015_105.tif.assetdownload',
#  'NIWeek_2015_105.tif.assetdownload.zip',
#  'NIWeek_2015_106.tif.assetdownload',
#  'NIWeek_2015_106.tif.assetdownload (1)',
#  'NIWeek_2015_106.tif.assetdownload (1).zip',
#  'NIWeek_2015_106.tif.assetdownload.zip',
#  'NI_STS_LoadBoard_DesignProcess_Ver1.1.pdf',
#  'ni_support.zip',
#  'OF03779-20130921692.PDF',
#  'ON Semiconductor Takes a New Approach to Production Test_Semi (1).pdf',
#  'ON Semiconductor Takes a New Approach to Production Test_Semi.pdf',
#  'OneDrive.zip',
#  'OneDrive_1_7-31-2019.zip',
#  'OneDrive_2019-07-31.zip',
#  'OneDrive_2020-03-02.zip',
#  'OneDrive_2020-03-06.zip',
#  'Oscilloscope Platform Health Data.csv',
#  'OSRAM LiDAR Presentation 2018.pdf',
#  'Outcome Driven Innovation (ODI) - The Theory and the Practice.pptx',
#  'OVA Return April.pdf',
#  'PA-238(G-May2013)(7078-TRX)_1.pdf',
#  'PA-916(A-Jun2005)(Model2600)1_1.pdf',
#  'PA-917(B-Nov2006)(8101-PIV)_1.pdf',
#  'PA-960(B-Jun2008)(2600).pdf',
#  'Panasonic STS configuraion 2DUT with SMU%E3%80%8020181203.pptx',
#  'Parallel For-Loop Research Update 2017-Apr-17.pptx',
#  'Parametric Analyzer Competition.pptx',
#  'Parametric Test for Next-Generation Semiconductor Technologies.pdf',
#  'Parametric Test with NI SMUs Demo Script (1).docx',
#  'Parametric Test with NI SMUs Demo Script.docx',
#  'PCap02_DS000319_1-00.zip',
#  'Period End - Billings (1).xlsx',
#  'Period End - Billings (2).xlsx',
#  'Period End - Billings - Order Range (1).xlsx',
#  'Period End - Billings - Order Range (2).xlsx',
#  'Period End - Billings - Order Range (3).xlsx',
#  'Period End - Billings - Order Range.xlsx',
#  'Period End - Billings.xlsx',
#  'Phase Plan template - ppt.pptx',
#  'Phase-Matrix-frequency-synthesizer-spans-0-2-GHz-to-20-GHz.pdf',
#  'Pipeline Review Meeting @ Nov.pptx',
#  'PM14XX LabVIEW (8.6) Instrument Drivers Installer.zip',
#  'pm57xb',
#  'pm57xb.zip',
#  'PMA - Template 2018.docx',
#  'PMI Forecast 2019 and 2020.xlsx',
#  'PMIC Demo (1).mp4',
#  'PMIC Demo.mp4',
#  'PMIC Demo.zip',
#  'POD_7034930210.pdf',
#  'Politecno Milano Parametric Test overview.pptx',
#  'Precision DC - FSE Bootcamp Training - 2017.pptx',
#  'Product EOL Infrastructure.pptx',
#  'Product EOL Phase Gates and Phases - Check Points.docx',
#  'Product Obsolescence Process.pdf',
#  'Product Performance Trends and Comparisons.twbx',
#  'product-data-sheet-ultrasonic-sensors-generation-6.pdf',
#  'Program.cs',
#  'Project Hours by Activity (1).xlsx',
#  'Project Hours by Activity.xlsx',
#  'ProjectFinancialTool.xlsm',
#  'ProjectName_Definition_GNG.pptx',
#  'PSRR Testing using SMU sequence.docx',
#  'Pulsed DC POC_with looping.vi',
#  'Pulse_Guide2.pdf',
#  'pxi-source-measure-unit_latest_en.nihelp',
#  'PXIe-4139 Broadcom Issue (1).pptx',
#  'PXIe-4139 Broadcom Issue.pptx',
#  'PXIe-4145 Voltage Stability Improvements for Battery Test System.docx',
#  'PXIe-4147_GSG_Review02.pdf',
#  'pxie-6570-getting-started-guide-national.pdf',
#  'PXIe-8135.rdp',
#  'PXIe_ITeam_Doc_rev2.1_25Jun10.pdf',
#  'Py-DS-ML-Bootcamp-master',
#  'Py-DS-ML-Bootcamp-master.zip',
#  'python-3.8.1-amd64-webinstall.exe',
#  'Q2 2020 PoR Roadmap.twbx',
#  'Q2 Plan of Record Roadmap.twbx',
#  'Q4 2017 Success Stories -NI ASEAN.pptx',
#  'QPA2705 Data Sheet.pdf',
#  'QPA3503 Data Sheet.pdf',
#  'QPF4001 Data Sheet.pdf',
#  'Qualify-Advance - Introduction to PXI Platform.pdf',
#  'query (1).iqy',
#  'query.iqy',
#  'quicksyn (1)',
#  'quicksyn (1).zip',
#  'QuickSyn Bookings 2016 to 2019.xlsx',
#  'QuickSyn.zip',
#  'Radar Altimeter Simulator material availability.xlsx',
#  'Radar Altimeter Simulator material availability_FreeFlight.pdf',
#  'Radar Altimeter Simulator material availability_FreeFlight.xlsx',
#  'RampRate QuasiCVAppNote1 (1).pdf',
#  'RampRate QuasiCVAppNote1.pdf',
#  'ReadMe (1).txt',
#  'ReadMe.txt',
#  'ReadMeFiles.zip',
#  'registrants VIP+AF 2005-2017.xlsx',
#  'ResistanceMeasurementError (1).xlsx',
#  'ResistanceMeasurementError.xlsx',
#  'retirementcalculator.xlsx',
#  'RingOscillatorWP (1).pdf',
#  'RingOscillatorWP.pdf',
#  'ROAL-600.pdf',
#  'ScreenToGif.2.17.1.Setup.msi',
#  'SCSA_IntelCorporation_HiBR_05082018.pdf',
#  'Self Oscillation Test Block Diagram.pptx',
#  'Semiconductor - Session Abstracts.docx',
#  'Sensor module power measurement, NI.pptx',
#  'sensors-17-01312.pdf',
#  'Ser2400 (1).pdf',
#  'Ser2400 (2).pdf',
#  'Ser2400 (3).pdf',
#  'Ser2400 (4).pdf',
#  'Ser2400.pdf',
#  'Setup.X86.en-us_O365ProPlusRetail_05324e9c-27ec-472d-8751-209945f49ca7_TX_PR_b_32_.exe',
#  'Short SMU Overview and One Sliders.pptx',
#  'Signal Calculation Modular (1).vi',
#  'Signal Calculation Modular.vi',
#  'signed_packet_file_lease_document_12768689_1553900154.pdf',
#  'SkypeMeetingsApp.msi',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018 (1).pptx',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018 (2).pptx',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018 (3).pptx',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018.pptx',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018_KB (1).pptx',
#  'SMU - Optimizing for High Throughput Testing - 11Jan2018_KB.pptx',
#  'SMU - Optimizing for High Throughput Testing.pptx',
#  'SMU - Programming Fundamentals - 24Aug2017.pptx',
#  'SMU Competitive Overview for Sales.pptx',
#  'SMU IO.vi',
#  'SMU Selection Guide.pdf',
#  'SMU Tables.docx',
#  'SMU Workshop_2017.pptx',
#  'SMU+Alarms.doc',
#  'SMU_Selector_Guide_1KW-61458-0_101618.pdf',
#  'SPEC-2606BB_System_SourceMeter_May_2018.pdf',
#  'SPEC-2651A_E_Feb2017_Customer (1).pdf',
#  'SPEC-2651A_E_Feb2017_Customer (2).pdf',
#  'SPEC-2651A_E_Feb2017_Customer.pdf',
#  'SPEC-2657AB_Dec2012_Customer.pdf',
#  'SPEC_2612BB_May2013.pdf',
#  'SpotifySetup.exe',
#  'Spring Pin Block Pinouts.xlsx',
#  'STS Datasheet.pdf',
#  'STS Order Billings (1).xlsx',
#  'STS Order Billings (2).xlsx',
#  'STS Order Billings.xlsx',
#  'STS Orders.xlsx',
#  'STS Supported Instrument Specifications 03-2019.zip',
#  'Summary of PXIe-4136 Issue at HiSilicon - 2018-08-30.pptx',
#  'sw_products_to_be_assigned_to_cfc_Jake_Harnack.xls',
#  'system configuration connector type.pptx',
#  'SystemSMU_SpeedThroughput_Poster.pdf',
#  'TableauAutoUpdate',
#  'TableauReader-64bit-2019-3-0.exe',
#  'TableauReader-64bit-2019-4-0.exe',
#  'Teams_windows_x64.exe',
#  'TeamViewer_Setup.exe',
#  'Teradyne Eagle Competitive Analysis.url',
#  'Teradyne Multisite Execution and Instrument Control.pptx',
#  'Tester 3 comparison of gage data dependent on the sense lines termination.xlsx',
#  'TestFixtures (1).pdf',
#  'TestFixtures.pdf',
#  'tests for adv seq reconfig benchmarking.zip',
#  'Texas Instruments - Charlie Moore - Regional.pptx',
#  'TI_TPS54360_PMIC_Datasheet.pdf',
#  'ToDate Summary - Billings - Geography (1).xlsx',
#  'ToDate Summary - Billings - Geography.xlsx',
#  'ToDate Summary - Billings - Stripe (1).xlsx',
#  'ToDate Summary - Billings - Stripe.xlsx',
#  'Top 25 YTD Master Org List (1).xlsx',
#  'Top 25 YTD Master Org List (2).xlsx',
#  'Top 25 YTD Master Org List.xlsx',
#  'Total_Cost_Ownership.pdf',
#  'tp_usbc_dock.exe',
#  'TS3324-Rousselin_Burnett_20140806 (1).pdf',
#  'TS3324-Rousselin_Burnett_20140806.pdf',
#  'TSMC Capacitance Overview.pdf',
#  'Upcoming Appointment (1).ics',
#  'Upcoming Appointment (10).ics',
#  'Upcoming Appointment (11).ics',
#  'Upcoming Appointment (12).ics',
#  'Upcoming Appointment (13).ics',
#  'Upcoming Appointment (14).ics',
#  'Upcoming Appointment (15).ics',
#  'Upcoming Appointment (16).ics',
#  'Upcoming Appointment (17).ics',
#  'Upcoming Appointment (18).ics',
#  'Upcoming Appointment (2).ics',
#  'Upcoming Appointment (3).ics',
#  'Upcoming Appointment (4).ics',
#  'Upcoming Appointment (5).ics',
#  'Upcoming Appointment (6).ics',
#  'Upcoming Appointment (7).ics',
#  'Upcoming Appointment (8).ics',
#  'Upcoming Appointment (9).ics',
#  'Upcoming Appointment.ics',
#  'Verigy PMU Presentation.pdf',
#  'VID_20180515_094447.mp4',
#  'VIP 2018_Registration Update_4 weeeks_26.09.2018.xls',
#  'VPN_Installer (1).EXE',
#  'VPN_Installer.EXE',
#  'Wedding Invite List (1).xlsx',
#  'Wedding Invite List.xlsx',
#  'WGVuQXBwNzguZWJpeg-- (1).ica',
#  'WGVuQXBwNzguZWJpeg-- (2).ica',
#  'WGVuQXBwNzguZWJpeg-- (3).ica',
#  'WGVuQXBwNzguZWJpeg-- (4).ica',
#  'WGVuQXBwNzguZWJpeg-- (5).ica',
#  'WGVuQXBwNzguZWJpeg-- (6).ica',
#  'WGVuQXBwNzguZWJpeg-- (7).ica',
#  'WGVuQXBwNzguZWJpeg--.ica',
#  'WLR_DS (1).pdf',
#  'WLR_DS.pdf',
#  'Zocdoc_Appointment (1).ics',
#  'Zocdoc_Appointment.ics',
#  'Zola RSVPs_Dec 9.xlsx',
#  'zola_guest_list_template.csv',
#  '[0680Z000004zBqD] Wafer Test  Proposal for Intel.pptx',
#  '[mail] RE_ Sensortek Light Sensor OPP.msg',
#  '[Tektronix+Webinar]+Characterization+for+Research_+Improving+Speed+and+Accuracy.ics',
#  '[Tektronix+Webinar]+Overcoming+DC+and+AC+Measurement+Challenges+of+Semiconductor+Devices+&+Materials.ics',
#  '_Easy Button_ Billings Pull (1).xlsx',
#  '_Easy Button_ Billings Pull.xlsx',
#  '_Easy Button_ Bookings Pull.xlsx',
#  '~$Guest-List-Template-Personal (1).xlsx',
#  '~$Wedding Invite List.xlsx',
#  '晶圓量產電性量測技巧.pdf']

# %% [markdown]
# ## make and rename directory

# %%
os.mkdir('C:\\Users\\Dan\\Google Drive\\python course\\new_dir')

# %%
os.rename('C:\\Users\\Dan\\Google Drive\\python course\\new_dir','C:\\Users\\Dan\\Google Drive\\python course\\new_dir2')

# %% [markdown]
# ## create and edit file

# %%
file = open('C:\\Users\\Dan\\Google Drive\\python course\\new_dir2\\myTXTfile.txt','w')
file.write('hello\n')
file.write('world!')
file.close()
